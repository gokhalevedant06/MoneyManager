# %%
import yfinance as yf
import datetime

# %%
now = datetime.datetime.now().date()
str(now)
# Out:
# '2021-03-09'

# %%
data = yf.download("^BSESN", start="2021-03-08", end=str(now), interval='1m')
data
# Out:
# [*********************100%***********************]  1 of 1 completed
#                                    Open          High           Low  \
# Datetime
# 2021-03-08 09:15:00+05:30  50604.968750  50731.199219  50577.300781
# 2021-03-08 09:16:00+05:30  50705.988281  50705.988281  50615.171875
# 2021-03-08 09:17:00+05:30  50679.191406  50680.621094  50639.011719
# 2021-03-08 09:18:00+05:30  50673.769531  50743.789062  50661.679688
# 2021-03-08 09:19:00+05:30  50735.730469  50748.300781  50709.769531
# ...                                 ...           ...           ...
# 2021-03-08 15:25:00+05:30  50479.601562  50483.921875  50464.179688
# 2021-03-08 15:26:00+05:30  50477.828125  50481.761719  50456.289062
# 2021-03-08 15:27:00+05:30  50456.449219  50471.531250  50451.910156
# 2021-03-08 15:28:00+05:30  50472.570312  50472.570312  50444.718750
# 2021-03-08 15:29:00+05:30  50459.121094  50474.378906  50441.519531
#
#                                   Close     Adj Close  Volume
# ...

# %%
for i in range(len(data)):
    print(data['Open'][i])
# Out:
# 50604.96875
# 50705.98828125
# 50679.19140625
# 50673.76953125
# 50735.73046875
# 50735.80859375
# 50680.71875
# 50679.76171875
# 50684.80859375
# 50694.7109375
# 50732.46875
# 50733.9609375
# 50722.75
# 50733.01171875
# 50729.19140625
# 50743.01953125
# 50780.80859375
# 50779.58984375
# 50735.69140625
# 50758.62109375
# 50709.859375
# 50711.01953125
# 50769.37109375
# 50752.2890625
# 50760.359375
# 50769.51953125
# 50737.21875
# 50755.98046875
# 50745.87890625
# 50713.578125
# 50716.37890625
# 50746.01171875
# 50739.5703125
# 50749.421875
# 50767.4609375
# 50777.62890625
# 50814.75
# 50871.98046875
# 50875.5703125
# 50892.359375
# 50868.26171875
# 50879.640625
# 50861.25
# 50869.19140625
# 50879.73046875
# 50908.98828125
# 50929.3203125
# 50944.25
# 50968.2890625
# 50945.37890625
# 50959.26171875
# 50955.19921875
# 50937.78125
# 50949.94140625
# 50908.5703125
# 50944.44921875
# 50929.48046875
# 50917.4296875
# 50944.4609375
# 50919.33984375
# 50915.890625
# 50874.87109375
# ...
