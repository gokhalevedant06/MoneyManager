# %%
# %config Completer.use_jedi = False

# %%
import pandas as pd
import plotly.express as px
import investpy
# Out:
# D:\CondaEnvironments\money_manager\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# D:\CondaEnvironments\money_manager\lib\site-packages\numpy\.libs\libopenblas.GK7GX5KEQ4F6UYO3P26ULGBQYHGQO7J4.gfortran-win_amd64.dll
# D:\CondaEnvironments\money_manager\lib\site-packages\numpy\.libs\libopenblas.WCDJNK7YVMPZQ2ME2ZZHJJRJ3JIKNDB7.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
df = investpy.get_index_historical_data(index="Nifty 50", from_date="01/01/2011", to_date="01/01/2021", country="india")
df.head()
# Out:
#                Open     High      Low    Close     Volume Currency
# Date
# 2011-01-03  6177.45  6178.55  6147.20  6157.60   96029000      INR
# 2011-01-04  6172.75  6181.05  6124.40  6146.35  181728000      INR
# 2011-01-05  6141.35  6141.35  6062.35  6079.80  139614000      INR
# 2011-01-06  6107.00  6116.15  6022.30  6048.25  152339008      INR
# 2011-01-07  6030.90  6051.20  5883.60  5904.60  171808992      INR

# %%
df = df.drop(columns=['Volume', 'Currency'])
df.head()
# Out:
#                Open     High      Low    Close
# Date
# 2011-01-03  6177.45  6178.55  6147.20  6157.60
# 2011-01-04  6172.75  6181.05  6124.40  6146.35
# 2011-01-05  6141.35  6141.35  6062.35  6079.80
# 2011-01-06  6107.00  6116.15  6022.30  6048.25
# 2011-01-07  6030.90  6051.20  5883.60  5904.60

# %%
    date = df.index.strftime("%b %d %Y")
    date = date.to_flat_index()

# %%
    df.reset_index(inplace=True, drop=True)
    df.set_index(date, inplace=True, drop=True)
    df.head()
# Out:
#                 Open     High      Low    Close
# Date
# Jan 03 2011  6177.45  6178.55  6147.20  6157.60
# Jan 04 2011  6172.75  6181.05  6124.40  6146.35
# Jan 05 2011  6141.35  6141.35  6062.35  6079.80
# Jan 06 2011  6107.00  6116.15  6022.30  6048.25
# Jan 07 2011  6030.90  6051.20  5883.60  5904.60

# %%
px.line()

# %%
df.columns
{i:i for i in df.columns}
# Out:
# {'Open': 'Open', 'High': 'High', 'Low': 'Low', 'Close': 'Close'}
